# %% [markdown]
# ##SINESP

# %%
import pandas as pd
import plotly.express as px

# %%
sinesp = pd.read_excel('sinesp.xlsx')

# %%
#descobrindo o tipo dos dados
sinesp.dtypes
# Out:
# Ano                           int64
# UF                           object
# Raça/Cor                     object
# Faixa etária                 object
# Escolaridade                 object
# Violência Sexual (SINESP)     int64
# dtype: object

# %%
#olhando a base
sinesp.head(10)
# Out:
#     Ano  UF        Raça/Cor  Faixa etária              Escolaridade  \
# 0  2018  PR          Branca  00 a 17 anos            Sem informação
# 1  2018  RJ           Parda  00 a 17 anos  Até fundamental completo
# 2  2018  RJ          Branca  00 a 17 anos  Até fundamental completo
# 3  2018  PR           Parda  00 a 17 anos            Sem informação
# 4  2018  SC  Sem informação  00 a 17 anos            Sem informação
# 5  2018  MT  Sem informação  00 a 17 anos            Sem informação
# 6  2018  PR  Sem informação  00 a 17 anos            Sem informação
# 7  2018  RJ           Preta  00 a 17 anos  Até fundamental completo
# 8  2018  PE           Parda  00 a 17 anos            Sem informação
# 9  2018  AM  Sem informação  00 a 17 anos            Sem informação
#
#    Violência Sexual (SINESP)
# 0                        322
# 1                        203
# 2                        173
# 3                        163
# 4                        123
# 5                        112
# 6                         75
# 7                         68
# 8                         61
# 9                         51

# %%
#excluir 2023

ano_a_remover = sinesp[(sinesp['Ano'] == 2023)].index

dados_sinesp = sinesp.drop(ano_a_remover)
dados_sinesp
# Out:
#        Ano  UF        Raça/Cor    Faixa etária              Escolaridade  \
# 0     2018  PR          Branca    00 a 17 anos            Sem informação
# 1     2018  RJ           Parda    00 a 17 anos  Até fundamental completo
# 2     2018  RJ          Branca    00 a 17 anos  Até fundamental completo
# 3     2018  PR           Parda    00 a 17 anos            Sem informação
# 4     2018  SC  Sem informação    00 a 17 anos            Sem informação
# ...    ...  ..             ...             ...                       ...
# 3840  2022  RJ           Parda  Sem informação  Até fundamental completo
# 3841  2022  RO          Branca  Sem informação            Sem informação
# 3842  2022  RO           Preta  Sem informação            Sem informação
# 3843  2022  RO  Sem informação  Sem informação            Sem informação
# 3844  2022  TO  Sem informação  Sem informação            Sem informação
#
#       Violência Sexual (SINESP)
# 0                           322
# 1                           203
# 2                           173
# 3                           163
# 4                           123
# ...                         ...
# 3840                          1
# 3841                          1
# 3842                          1
# 3843                          1
# 3844                          1
#
# [3150 rows x 6 columns]

# %%
#excluir as UFs SP, MG, RJ, DF
estado_a_remover_sinesp = dados_sinesp[(dados_sinesp['UF'] == 'SP')|(dados_sinesp['UF'] == 'RJ')|(dados_sinesp['UF'] == 'MG')|(dados_sinesp['UF'] == 'DF')].index

sinesp_oficial = dados_sinesp.drop(estado_a_remover_sinesp)
sinesp_oficial
# Out:
#        Ano  UF        Raça/Cor    Faixa etária    Escolaridade  \
# 0     2018  PR          Branca    00 a 17 anos  Sem informação
# 3     2018  PR           Parda    00 a 17 anos  Sem informação
# 4     2018  SC  Sem informação    00 a 17 anos  Sem informação
# 5     2018  MT  Sem informação    00 a 17 anos  Sem informação
# 6     2018  PR  Sem informação    00 a 17 anos  Sem informação
# ...    ...  ..             ...             ...             ...
# 3839  2022  PR           Preta  Sem informação  Sem informação
# 3841  2022  RO          Branca  Sem informação  Sem informação
# 3842  2022  RO           Preta  Sem informação  Sem informação
# 3843  2022  RO  Sem informação  Sem informação  Sem informação
# 3844  2022  TO  Sem informação  Sem informação  Sem informação
#
#       Violência Sexual (SINESP)
# 0                           322
# 3                           163
# 4                           123
# 5                           112
# 6                            75
# ...                         ...
# 3839                          1
# 3841                          1
# 3842                          1
# 3843                          1
# 3844                          1
#
# [2766 rows x 6 columns]

# %%
#renomeando colunas

sinesp_oficial.rename(columns={'Raça/Cor': 'raça_cor'}, inplace=True)
sinesp_oficial.rename(columns={'Violência Sexual (SINESP)': 'Sinesp'}, inplace=True)
sinesp_oficial.rename(columns={'Faixa etária': 'faixa_etaria'}, inplace=True)
sinesp_oficial
# Out:
#        Ano  UF        raça_cor    faixa_etaria    Escolaridade  Sinesp
# 0     2018  PR          Branca    00 a 17 anos  Sem informação     322
# 3     2018  PR           Parda    00 a 17 anos  Sem informação     163
# 4     2018  SC  Sem informação    00 a 17 anos  Sem informação     123
# 5     2018  MT  Sem informação    00 a 17 anos  Sem informação     112
# 6     2018  PR  Sem informação    00 a 17 anos  Sem informação      75
# ...    ...  ..             ...             ...             ...     ...
# 3839  2022  PR           Preta  Sem informação  Sem informação       1
# 3841  2022  RO          Branca  Sem informação  Sem informação       1
# 3842  2022  RO           Preta  Sem informação  Sem informação       1
# 3843  2022  RO  Sem informação  Sem informação  Sem informação       1
# 3844  2022  TO  Sem informação  Sem informação  Sem informação       1
#
# [2766 rows x 6 columns]

# %%
#groupby raca
sinesp_raca = sinesp_oficial.groupby(["Ano", "raça_cor"])[["Sinesp"]].sum().reset_index()
sinesp_raca
# Out:
#      Ano        raça_cor  Sinesp
# 0   2018         Amarela      35
# 1   2018          Branca    1370
# 2   2018        Indígena       7
# 3   2018           Parda    1323
# 4   2018           Preta     197
# 5   2018  Sem informação    2227
# 6   2019         Amarela      23
# 7   2019          Branca    1388
# 8   2019        Indígena      15
# 9   2019           Parda    1807
# 10  2019           Preta     214
# 11  2019  Sem informação    4915
# 12  2020         Amarela      26
# 13  2020          Branca    1736
# 14  2020        Indígena      20
# 15  2020          Outros      12
# 16  2020           Parda    1630
# 17  2020           Preta     256
# 18  2020  Sem informação    4220
# 19  2021         Amarela      32
# 20  2021          Branca    1638
# 21  2021        Indígena      32
# 22  2021          Outros      39
# 23  2021           Parda    2227
# 24  2021           Preta     373
# 25  2021  Sem informação    4289
# 26  2022         Amarela      38
# 27  2022          Branca    1818
# 28  2022        Indígena      43
# 29  2022          Outros     111
# 30  2022           Parda    3102
# 31  2022           Preta     565
# 32  2022  Sem informação    4541

# %%
import plotly.express as px
# Convertendo a coluna 'Ano' para string
sinesp_raca['Ano'] = sinesp_raca['Ano'].astype(str)

# %%
#gráfico sinesp raça - linear
grafico_sinesp_raca_linear = px.line(sinesp_raca, x="Ano", y="Sinesp", color='raça_cor', markers=True,color_discrete_sequence=['#800080','#FFA500','#FFFF00','#008000','#0000FF','#FF0000'],
                       title="Número de Casos por Raça/Cor ao Longo dos Anos (Escala Linear) do Sinesp",
                       labels={"Sinesp": "Número de Casos (Sinesp)", "Ano": "Ano", "raça_cor": "Raça/Cor"})
grafico_sinesp_raca_linear.update_traces(text=sinesp_raca['Sinesp'], hoverinfo='text+x+y')
grafico_sinesp_raca_linear.update_yaxes(type='linear', tickmode='linear', tick0=0, dtick=500)  # Definindo intervalos de 500

# Exibindo o gráfico
grafico_sinesp_raca_linear.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2bfa49eb-5d93-472b-9bf0-73a6795e8b8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bfa49eb-5d93-472b-9bf0-73a6795e8b8c")) {                    Plotly.newPlot(                        "2bfa49eb-5d93-472b-9bf0-73a6795e8b8c",                        [{"hovertemplate":"Ra\u00e7a\u002fCor=Amarela\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amarela","line":{"color":"#800080","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Amarela","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[35,23,26,32,38],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[35.0,1370.0,7.0,1323.0,197.0,2227.0,23.0,1388.0,15.0,1807.0,214.0,4915.0,26.0,1736.0,20.0,12.0,1630.0,256.0,4220.0,32.0,1638.0,32.0,39.0,2227.0,373.0,4289.0,38.0,1818.0,43.0,111.0,3102.0,565.0,4541.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Branca\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Branca","line":{"color":"#FFA500","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Branca","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[1370,1388,1736,1638,1818],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[35.0,1370.0,7.0,1323.0,197.0,2227.0,23.0,1388.0,15.0,1807.0,214.0,4915.0,26.0,1736.0,20.0,12.0,1630.0,256.0,4220.0,32.0,1638.0,32.0,39.0,2227.0,373.0,4289.0,38.0,1818.0,43.0,111.0,3102.0,565.0,4541.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Ind\u00edgena\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ind\u00edgena","line":{"color":"#FFFF00","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ind\u00edgena","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[7,15,20,32,43],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[35.0,1370.0,7.0,1323.0,197.0,2227.0,23.0,1388.0,15.0,1807.0,214.0,4915.0,26.0,1736.0,20.0,12.0,1630.0,256.0,4220.0,32.0,1638.0,32.0,39.0,2227.0,373.0,4289.0,38.0,1818.0,43.0,111.0,3102.0,565.0,4541.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Parda\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Parda","line":{"color":"#008000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Parda","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[1323,1807,1630,2227,3102],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[35.0,1370.0,7.0,1323.0,197.0,2227.0,23.0,1388.0,15.0,1807.0,214.0,4915.0,26.0,1736.0,20.0,12.0,1630.0,256.0,4220.0,32.0,1638.0,32.0,39.0,2227.0,373.0,4289.0,38.0,1818.0,43.0,111.0,3102.0,565.0,4541.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Preta\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Preta","line":{"color":"#0000FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Preta","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[197,214,256,373,565],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[35.0,1370.0,7.0,1323.0,197.0,2227.0,23.0,1388.0,15.0,1807.0,214.0,4915.0,26.0,1736.0,20.0,12.0,1630.0,256.0,4220.0,32.0,1638.0,32.0,39.0,2227.0,373.0,4289.0,38.0,1818.0,43.0,111.0,3102.0,565.0,4541.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Sem informa\u00e7\u00e3o\u003cbr\u003eAno=%{x}\u003cbr\u0 ...

# %%
#groupby 2: escolaridade
sinesp_escolaridade = sinesp_oficial.groupby(["Ano", "Escolaridade"])[["Sinesp"]].sum().reset_index()
sinesp_escolaridade
# Out:
#      Ano              Escolaridade  Sinesp
# 0   2018  Até fundamental completo     672
# 1   2018     Ensino médio completo     259
# 2   2018  Ensino superior completo      62
# 3   2018            Sem informação    4100
# 4   2018             Sem instrução      66
# 5   2019  Até fundamental completo     975
# 6   2019     Ensino médio completo     292
# 7   2019  Ensino superior completo     431
# 8   2019            Sem informação    6577
# 9   2019             Sem instrução      87
# 10  2020  Até fundamental completo     968
# 11  2020     Ensino médio completo     382
# 12  2020  Ensino superior completo     376
# 13  2020            Sem informação    6138
# 14  2020             Sem instrução      36
# 15  2021  Até fundamental completo     797
# 16  2021     Ensino médio completo     376
# 17  2021  Ensino superior completo     466
# 18  2021            Sem informação    6955
# 19  2021             Sem instrução      36
# 20  2022  Até fundamental completo    1072
# 21  2022     Ensino médio completo     531
# 22  2022  Ensino superior completo     495
# 23  2022            Sem informação    8069
# 24  2022             Sem instrução      51

# %%
#gráfico sinesp escolaridade - linear

sinesp_escolaridade['Ano'] = sinesp_escolaridade['Ano'].astype(str)

grafico_sinesp_escolaridade = px.line(sinesp_escolaridade, x="Ano", y="Sinesp", color='Escolaridade', markers = True,color_discrete_sequence=['#FF7F7F','#779ECB','#77DD77','#CBAACB','#FFB347'],
              title="Número de Casos por Escolaridade ao Longo dos Anos (Escala Linear) do SINESP",
              labels={"Sinesp": "Número de Casos (Sinesp)", "Ano": "Ano", "escolaridade": "Escolaridade"})
grafico_sinesp_escolaridade.update_traces(text=sinesp_escolaridade['Sinesp'], hoverinfo='text+x+y')
grafico_sinesp_escolaridade.update_yaxes(type='linear')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="88b8952e-ab8b-454a-8a35-ed522ee3b153" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88b8952e-ab8b-454a-8a35-ed522ee3b153")) {                    Plotly.newPlot(                        "88b8952e-ab8b-454a-8a35-ed522ee3b153",                        [{"hovertemplate":"Escolaridade=At\u00e9 fundamental completo\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At\u00e9 fundamental completo","line":{"color":"#FF7F7F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"At\u00e9 fundamental completo","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[672,975,968,797,1072],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[672.0,259.0,62.0,4100.0,66.0,975.0,292.0,431.0,6577.0,87.0,968.0,382.0,376.0,6138.0,36.0,797.0,376.0,466.0,6955.0,36.0,1072.0,531.0,495.0,8069.0,51.0]},{"hovertemplate":"Escolaridade=Ensino m\u00e9dio completo\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensino m\u00e9dio completo","line":{"color":"#779ECB","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensino m\u00e9dio completo","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[259,292,382,376,531],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[672.0,259.0,62.0,4100.0,66.0,975.0,292.0,431.0,6577.0,87.0,968.0,382.0,376.0,6138.0,36.0,797.0,376.0,466.0,6955.0,36.0,1072.0,531.0,495.0,8069.0,51.0]},{"hovertemplate":"Escolaridade=Ensino superior completo\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensino superior completo","line":{"color":"#77DD77","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensino superior completo","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[62,431,376,466,495],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[672.0,259.0,62.0,4100.0,66.0,975.0,292.0,431.0,6577.0,87.0,968.0,382.0,376.0,6138.0,36.0,797.0,376.0,466.0,6955.0,36.0,1072.0,531.0,495.0,8069.0,51.0]},{"hovertemplate":"Escolaridade=Sem informa\u00e7\u00e3o\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sem informa\u00e7\u00e3o","line":{"color":"#CBAACB","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Sem informa\u00e7\u00e3o","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[4100,6577,6138,6955,8069],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[672.0,259.0,62.0,4100.0,66.0,975.0,292.0,431.0,6577.0,87.0,968.0,382.0,376.0,6138.0,36.0,797.0,376.0,466.0,6955.0,36.0,1072.0,531.0,495.0,8069.0,51.0]},{"hovertemplate":"Escolaridade=Sem instru\u00e7\u00e3o\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sem instru\u00e7\u00e3o","line":{"color":"#FFB347","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Sem instru\u00e7\u00e3o","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[66,87,36,36,51],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[672.0,259.0,62.0,4100.0,66.0,975.0,292.0,431.0,6577.0,87.0,968.0,382.0,376.0,6138.0,36.0,797.0,376.0,466.0,6955.0,36.0,1072.0,531.0,495.0,8069.0,51.0]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","color ...

# %%
#groupby 3: faixa etária
sinesp_faixa = sinesp_oficial.groupby(["Ano", "faixa_etaria"])[["Sinesp"]].sum().reset_index()
sinesp_faixa
# Out:
#      Ano     faixa_etaria  Sinesp
# 0   2018     00 a 17 anos    1455
# 1   2018     18 a 29 anos    1049
# 2   2018     30 a 59 anos     899
# 3   2018  60 anos ou mais    1754
# 4   2018   Sem informação       2
# 5   2019     00 a 17 anos    2910
# 6   2019     18 a 29 anos    1828
# 7   2019     30 a 59 anos    1557
# 8   2019  60 anos ou mais    2059
# 9   2019   Sem informação       8
# 10  2020     00 a 17 anos    2960
# 11  2020     18 a 29 anos    2508
# 12  2020     30 a 59 anos    2079
# 13  2020  60 anos ou mais     338
# 14  2020   Sem informação      15
# 15  2021     00 a 17 anos    3059
# 16  2021     18 a 29 anos    2904
# 17  2021     30 a 59 anos    2441
# 18  2021  60 anos ou mais     202
# 19  2021   Sem informação      24
# 20  2022     00 a 17 anos    3740
# 21  2022     18 a 29 anos    3271
# 22  2022     30 a 59 anos    2896
# 23  2022  60 anos ou mais     272
# 24  2022   Sem informação      39

# %%
#gráfico faixa etária sinesp - escala linear

sinesp_faixa['Ano'] = sinesp_faixa['Ano'].astype(str)

grafico_sinesp_faixa = px.line(sinesp_faixa, x="Ano", y="Sinesp", color='faixa_etaria', markers = True,
              title="Número de Casos por Faixa Etária ao Longo dos Anos (Escala Linear) do SINESP",
              labels={"Sinesp": "Número de Casos (Sinesp)", "Ano": "Ano", "faixa_etaria": "Faixa Etária"})
grafico_sinesp_faixa.update_traces(text=sinesp_faixa['Sinesp'], hoverinfo='text+x+y')
grafico_sinesp_faixa.update_yaxes(type='linear')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fd040658-8d62-4ace-8896-aab542fde512" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd040658-8d62-4ace-8896-aab542fde512")) {                    Plotly.newPlot(                        "fd040658-8d62-4ace-8896-aab542fde512",                        [{"hovertemplate":"Faixa Et\u00e1ria=00 a 17 anos\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"00 a 17 anos","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"00 a 17 anos","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[1455,2910,2960,3059,3740],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[1455.0,1049.0,899.0,1754.0,2.0,2910.0,1828.0,1557.0,2059.0,8.0,2960.0,2508.0,2079.0,338.0,15.0,3059.0,2904.0,2441.0,202.0,24.0,3740.0,3271.0,2896.0,272.0,39.0]},{"hovertemplate":"Faixa Et\u00e1ria=18 a 29 anos\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"18 a 29 anos","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"18 a 29 anos","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[1049,1828,2508,2904,3271],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[1455.0,1049.0,899.0,1754.0,2.0,2910.0,1828.0,1557.0,2059.0,8.0,2960.0,2508.0,2079.0,338.0,15.0,3059.0,2904.0,2441.0,202.0,24.0,3740.0,3271.0,2896.0,272.0,39.0]},{"hovertemplate":"Faixa Et\u00e1ria=30 a 59 anos\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"30 a 59 anos","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"30 a 59 anos","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[899,1557,2079,2441,2896],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[1455.0,1049.0,899.0,1754.0,2.0,2910.0,1828.0,1557.0,2059.0,8.0,2960.0,2508.0,2079.0,338.0,15.0,3059.0,2904.0,2441.0,202.0,24.0,3740.0,3271.0,2896.0,272.0,39.0]},{"hovertemplate":"Faixa Et\u00e1ria=60 anos ou mais\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"60 anos ou mais","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"60 anos ou mais","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[1754,2059,338,202,272],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[1455.0,1049.0,899.0,1754.0,2.0,2910.0,1828.0,1557.0,2059.0,8.0,2960.0,2508.0,2079.0,338.0,15.0,3059.0,2904.0,2441.0,202.0,24.0,3740.0,3271.0,2896.0,272.0,39.0]},{"hovertemplate":"Faixa Et\u00e1ria=Sem informa\u00e7\u00e3o\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinesp)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sem informa\u00e7\u00e3o","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Sem informa\u00e7\u00e3o","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[2,8,15,24,39],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[1455.0,1049.0,899.0,1754.0,2.0,2910.0,1828.0,1557.0,2059.0,8.0,2960.0,2508.0,2079.0,338.0,15.0,3059.0,2904.0,2441.0,202.0,24.0,3740.0,3271.0,2896.0,272.0,39.0]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111 ...

# %% [markdown]
# # SINAN

# %%
sinan = pd.read_excel('sinan.xlsx')

# %%
#descobrindo o tipo dos dados
sinan.dtypes
# Out:
# Ano                          int64
# UF                          object
# Raça/Cor                    object
# Faixa etária                object
# Escolaridade                object
# Violência Sexual (SINAN)     int64
# dtype: object

# %%
sinan.head(10)
# Out:
#     Ano  UF        Raça/Cor  Faixa etária              Escolaridade  \
# 0  2011  AC         Amarela  00 a 17 anos     Ensino médio completo
# 1  2011  AC          Branca  00 a 17 anos  Até fundamental completo
# 2  2011  AC          Branca  00 a 17 anos     Ensino médio completo
# 3  2011  AC          Branca  00 a 17 anos            Sem informação
# 4  2011  AC           Parda  00 a 17 anos  Até fundamental completo
# 5  2011  AC           Parda  00 a 17 anos     Ensino médio completo
# 6  2011  AC           Parda  00 a 17 anos  Ensino superior completo
# 7  2011  AC           Parda  00 a 17 anos            Sem informação
# 8  2011  AC           Preta  00 a 17 anos     Ensino médio completo
# 9  2011  AC  Sem informação  00 a 17 anos  Até fundamental completo
#
#    Violência Sexual (SINAN)
# 0                         1
# 1                         3
# 2                        14
# 3                         5
# 4                        51
# 5                       150
# 6                         1
# 7                        23
# 8                         1
# 9                         1

# %%
ano_sinan_remover = sinan[( sinan['Ano'] == 2011) | ( sinan['Ano'] == 2012) | ( sinan['Ano'] == 2013)  | ( sinan['Ano'] == 2014) | ( sinan['Ano'] == 2015) | ( sinan['Ano'] == 2016) |( sinan['Ano'] == 2017) | ( sinan['Ano'] == 2023)].index

dados_sinan = sinan.drop(ano_sinan_remover)
dados_sinan
# Out:
#         Ano  UF        Raça/Cor     Faixa etária              Escolaridade  \
# 8299   2018  AC         Amarela     00 a 17 anos     Ensino médio completo
# 8300   2018  AC         Amarela     00 a 17 anos            Sem informação
# 8301   2018  AC          Branca     00 a 17 anos  Até fundamental completo
# 8302   2018  AC          Branca     00 a 17 anos     Ensino médio completo
# 8303   2018  AC          Branca     00 a 17 anos  Ensino superior completo
# ...     ...  ..             ...              ...                       ...
# 15216  2022  SP           Preta  60 anos ou mais            Sem informação
# 15217  2022  SP  Sem informação  60 anos ou mais            Sem informação
# 15218  2022  TO           Parda  60 anos ou mais  Até fundamental completo
# 15219  2022  TO           Parda  60 anos ou mais            Sem informação
# 15220  2022  TO           Preta  60 anos ou mais  Ensino superior completo
#
#        Violência Sexual (SINAN)
# 8299                          1
# 8300                          2
# 8301                          4
# 8302                         20
# 8303                          1
# ...                         ...
# 15216                         5
# 15217                         1
# 15218                         1
# 15219                         2
# 15220                         1
#
# [6922 rows x 6 columns]

# %%
estado_a_remover = dados_sinan[(dados_sinan['UF'] == 'SP')|(dados_sinan['UF'] == 'RJ')|(dados_sinan['UF'] == 'MG')|(dados_sinan['UF'] == 'DF')].index

sinan_oficial = dados_sinan.drop(estado_a_remover)
sinan_oficial
# Out:
#         Ano              UF Raça/Cor     Faixa etária  \
# 8299   2018              AC  Amarela     00 a 17 anos
# 8300   2018              AC  Amarela     00 a 17 anos
# 8301   2018              AC   Branca     00 a 17 anos
# 8302   2018              AC   Branca     00 a 17 anos
# 8303   2018              AC   Branca     00 a 17 anos
# ...     ...             ...      ...              ...
# 15201  2022  Sem informação    Preta  60 anos ou mais
# 15202  2022  Sem informação    Preta  60 anos ou mais
# 15218  2022              TO    Parda  60 anos ou mais
# 15219  2022              TO    Parda  60 anos ou mais
# 15220  2022              TO    Preta  60 anos ou mais
#
#                    Escolaridade  Violência Sexual (SINAN)
# 8299      Ensino médio completo                         1
# 8300             Sem informação                         2
# 8301   Até fundamental completo                         4
# 8302      Ensino médio completo                        20
# 8303   Ensino superior completo                         1
# ...                         ...                       ...
# 15201  Até fundamental completo                         2
# 15202            Sem informação                         2
# 15218  Até fundamental completo                         1
# 15219            Sem informação                         2
# 15220  Ensino superior completo                         1
#
# [5526 rows x 6 columns]

# %%
sinan_oficial.rename(columns={'Raça/Cor': 'raça_cor'}, inplace=True)
sinan_oficial.rename(columns={'Violência Sexual (SINAN)': 'Sinan'}, inplace=True)
sinan_oficial.rename(columns={'Faixa etária': 'faixa_etaria'}, inplace=True)
sinan_oficial
# Out:
#         Ano              UF raça_cor     faixa_etaria  \
# 8299   2018              AC  Amarela     00 a 17 anos
# 8300   2018              AC  Amarela     00 a 17 anos
# 8301   2018              AC   Branca     00 a 17 anos
# 8302   2018              AC   Branca     00 a 17 anos
# 8303   2018              AC   Branca     00 a 17 anos
# ...     ...             ...      ...              ...
# 15201  2022  Sem informação    Preta  60 anos ou mais
# 15202  2022  Sem informação    Preta  60 anos ou mais
# 15218  2022              TO    Parda  60 anos ou mais
# 15219  2022              TO    Parda  60 anos ou mais
# 15220  2022              TO    Preta  60 anos ou mais
#
#                    Escolaridade  Sinan
# 8299      Ensino médio completo      1
# 8300             Sem informação      2
# 8301   Até fundamental completo      4
# 8302      Ensino médio completo     20
# 8303   Ensino superior completo      1
# ...                         ...    ...
# 15201  Até fundamental completo      2
# 15202            Sem informação      2
# 15218  Até fundamental completo      1
# 15219            Sem informação      2
# 15220  Ensino superior completo      1
#
# [5526 rows x 6 columns]

# %%
#groupby 1: raça
sinan_raca = sinan_oficial.groupby(["Ano", "raça_cor"])[["Sinan"]].sum().reset_index()
sinan_raca
# Out:
#      Ano        raça_cor  Sinan
# 0   2018         Amarela    172
# 1   2018          Branca   6913
# 2   2018        Indígena    275
# 3   2018           Parda  10332
# 4   2018           Preta   1519
# 5   2018  Sem informação    686
# 6   2019         Amarela    173
# 7   2019          Branca   7696
# 8   2019        Indígena    380
# 9   2019           Parda  11528
# 10  2019           Preta   1746
# 11  2019  Sem informação    779
# 12  2020         Amarela    216
# 13  2020          Branca   6288
# 14  2020        Indígena    280
# 15  2020           Parda  10355
# 16  2020           Preta   1471
# 17  2020  Sem informação    688
# 18  2021         Amarela    235
# 19  2021          Branca   7225
# 20  2021        Indígena    339
# 21  2021           Parda  12910
# 22  2021           Preta   1833
# 23  2021  Sem informação    796
# 24  2022         Amarela    240
# 25  2022          Branca   9192
# 26  2022        Indígena    501
# 27  2022           Parda  15547
# 28  2022           Preta   2426
# 29  2022  Sem informação    970

# %%
#gráfico sinan raça - linear
import numpy as np

sinan_raca['Ano'] = sinan_raca['Ano'].astype(str)
grafico_sinan_raca_linear = px.line(sinan_raca, x="Ano", y="Sinan", color='raça_cor', markers=True, color_discrete_sequence=['#800080','#FFA500','#FFFF00','#008000','#0000FF','#FF0000'],
              title="Número de Casos por Raça/Cor ao Longo dos Anos (Escala Linear) do SINAN",
              labels={"Sinan": "Número de Casos (Sinan)", "Ano": "Ano", "raça_cor": "Raça/Cor"})

grafico_sinan_raca_linear.update_traces(text=sinan_raca['Sinan'], hoverinfo='text+x+y')

# Definindo os valores e os textos do eixo Y manualmente
max_value = sinan_raca['Sinan'].max()
tick_values = np.arange(0, max_value + 2000, 2000)  # Isso criará um array de 0 até o valor máximo, com incrementos de 500
tick_texts = [f'{int(value)}' for value in tick_values]  # Isso converte os valores para texto sem a abreviação 'k'

# Aplicando as configurações ao eixo Y
grafico_sinan_raca_linear.update_yaxes(type='linear', tickmode='array', tickvals=tick_values, ticktext=tick_texts)

# Exibindo o gráfico
grafico_sinan_raca_linear.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3c834d75-275f-4cef-8db6-f1c7e4bd2427" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c834d75-275f-4cef-8db6-f1c7e4bd2427")) {                    Plotly.newPlot(                        "3c834d75-275f-4cef-8db6-f1c7e4bd2427",                        [{"hovertemplate":"Ra\u00e7a\u002fCor=Amarela\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amarela","line":{"color":"#800080","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Amarela","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[172,173,216,235,240],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[172.0,6913.0,275.0,10332.0,1519.0,686.0,173.0,7696.0,380.0,11528.0,1746.0,779.0,216.0,6288.0,280.0,10355.0,1471.0,688.0,235.0,7225.0,339.0,12910.0,1833.0,796.0,240.0,9192.0,501.0,15547.0,2426.0,970.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Branca\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Branca","line":{"color":"#FFA500","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Branca","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[6913,7696,6288,7225,9192],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[172.0,6913.0,275.0,10332.0,1519.0,686.0,173.0,7696.0,380.0,11528.0,1746.0,779.0,216.0,6288.0,280.0,10355.0,1471.0,688.0,235.0,7225.0,339.0,12910.0,1833.0,796.0,240.0,9192.0,501.0,15547.0,2426.0,970.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Ind\u00edgena\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ind\u00edgena","line":{"color":"#FFFF00","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ind\u00edgena","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[275,380,280,339,501],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[172.0,6913.0,275.0,10332.0,1519.0,686.0,173.0,7696.0,380.0,11528.0,1746.0,779.0,216.0,6288.0,280.0,10355.0,1471.0,688.0,235.0,7225.0,339.0,12910.0,1833.0,796.0,240.0,9192.0,501.0,15547.0,2426.0,970.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Parda\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Parda","line":{"color":"#008000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Parda","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[10332,11528,10355,12910,15547],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[172.0,6913.0,275.0,10332.0,1519.0,686.0,173.0,7696.0,380.0,11528.0,1746.0,779.0,216.0,6288.0,280.0,10355.0,1471.0,688.0,235.0,7225.0,339.0,12910.0,1833.0,796.0,240.0,9192.0,501.0,15547.0,2426.0,970.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Preta\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Preta","line":{"color":"#0000FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Preta","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[1519,1746,1471,1833,2426],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[172.0,6913.0,275.0,10332.0,1519.0,686.0,173.0,7696.0,380.0,11528.0,1746.0,779.0,216.0,6288.0,280.0,10355.0,1471.0,688.0,235.0,7225.0,339.0,12910.0,1833.0,796.0,240.0,9192.0,501.0,15547.0,2426.0,970.0]},{"hovertemplate":"Ra\u00e7a\u002fCor=Sem informa\u00e7\u00e3o\u003cbr\u003eAno ...

# %%
#groupby 2: escolaridade
sinan_escolaridade = sinan_oficial.groupby(["Ano", "Escolaridade"])[["Sinan"]].sum().reset_index()
sinan_escolaridade
# Out:
#      Ano              Escolaridade  Sinan
# 0   2018  Até fundamental completo   2761
# 1   2018     Ensino médio completo   8424
# 2   2018  Ensino superior completo   2085
# 3   2018            Sem informação   6627
# 4   2019  Até fundamental completo   2986
# 5   2019     Ensino médio completo   9315
# 6   2019  Ensino superior completo   2475
# 7   2019            Sem informação   7526
# 8   2020  Até fundamental completo   2510
# 9   2020     Ensino médio completo   7888
# 10  2020  Ensino superior completo   2170
# 11  2020            Sem informação   6730
# 12  2021  Até fundamental completo   2902
# 13  2021     Ensino médio completo   9941
# 14  2021  Ensino superior completo   2520
# 15  2021            Sem informação   7975
# 16  2022  Até fundamental completo   2381
# 17  2022     Ensino médio completo  10242
# 18  2022  Ensino superior completo   4828
# 19  2022            Sem informação  11425

# %%
#gráfico sinan escolaridade - linear
sinan_escolaridade['Ano'] = sinan_escolaridade['Ano'].astype(str)

grafico_sinan_escolaridade = px.line(sinan_escolaridade, x="Ano", y="Sinan", color='Escolaridade', markers=True,color_discrete_sequence=['#FF7F7F','#779ECB','#77DD77','#CBAACB','#FFB347'],
              title="Número de Casos por Escolaridade ao Longo dos Anos (Escala Linear) do SINAN",
              labels={"Sinan": "Número de Casos (Sinan)", "Ano": "Ano", "Escolaridade": "Escolaridade"})

grafico_sinan_escolaridade.update_traces(text=sinan_escolaridade['Sinan'], hoverinfo='text+x+y')
# Definindo os valores e os textos do eixo Y manualmente
max_value = sinan_escolaridade['Sinan'].max()
tick_values = np.arange(0, max_value + 2000, 2000)  # Isso criará um array de 0 até o valor máximo, com incrementos de 500
tick_texts = [f'{int(value)}' for value in tick_values]  # Isso converte os valores para texto sem a abreviação 'k'

# Aplicando as configurações ao eixo Y
grafico_sinan_escolaridade.update_yaxes(type='linear', tickmode='array', tickvals=tick_values, ticktext=tick_texts)

# Exibindo o gráfico
grafico_sinan_escolaridade.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2ef399d1-1b84-43dc-b741-a04b420d99ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ef399d1-1b84-43dc-b741-a04b420d99ff")) {                    Plotly.newPlot(                        "2ef399d1-1b84-43dc-b741-a04b420d99ff",                        [{"hovertemplate":"Escolaridade=At\u00e9 fundamental completo\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"At\u00e9 fundamental completo","line":{"color":"#FF7F7F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"At\u00e9 fundamental completo","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[2761,2986,2510,2902,2381],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[2761.0,8424.0,2085.0,6627.0,2986.0,9315.0,2475.0,7526.0,2510.0,7888.0,2170.0,6730.0,2902.0,9941.0,2520.0,7975.0,2381.0,10242.0,4828.0,11425.0]},{"hovertemplate":"Escolaridade=Ensino m\u00e9dio completo\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensino m\u00e9dio completo","line":{"color":"#779ECB","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensino m\u00e9dio completo","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[8424,9315,7888,9941,10242],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[2761.0,8424.0,2085.0,6627.0,2986.0,9315.0,2475.0,7526.0,2510.0,7888.0,2170.0,6730.0,2902.0,9941.0,2520.0,7975.0,2381.0,10242.0,4828.0,11425.0]},{"hovertemplate":"Escolaridade=Ensino superior completo\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensino superior completo","line":{"color":"#77DD77","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensino superior completo","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[2085,2475,2170,2520,4828],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[2761.0,8424.0,2085.0,6627.0,2986.0,9315.0,2475.0,7526.0,2510.0,7888.0,2170.0,6730.0,2902.0,9941.0,2520.0,7975.0,2381.0,10242.0,4828.0,11425.0]},{"hovertemplate":"Escolaridade=Sem informa\u00e7\u00e3o\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sem informa\u00e7\u00e3o","line":{"color":"#CBAACB","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Sem informa\u00e7\u00e3o","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[6627,7526,6730,7975,11425],"yaxis":"y","type":"scatter","hoverinfo":"text+x+y","text":[2761.0,8424.0,2085.0,6627.0,2986.0,9315.0,2475.0,7526.0,2510.0,7888.0,2170.0,6730.0,2902.0,9941.0,2520.0,7975.0,2381.0,10242.0,4828.0,11425.0]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...

# %%
#groupby 3: faixa etária
sinan_faixa = sinan_oficial.groupby(["Ano", "faixa_etaria"])[["Sinan"]].sum().reset_index()
sinan_faixa
# Out:
#      Ano     faixa_etaria  Sinan
# 0   2018     00 a 17 anos  14241
# 1   2018     18 a 29 anos   3143
# 2   2018     30 a 59 anos   2330
# 3   2018  60 anos ou mais    183
# 4   2019     00 a 17 anos  15808
# 5   2019     18 a 29 anos   3540
# 6   2019     30 a 59 anos   2719
# 7   2019  60 anos ou mais    207
# 8   2019   Sem informação     28
# 9   2020     00 a 17 anos  13551
# 10  2020     18 a 29 anos   3213
# 11  2020     30 a 59 anos   2327
# 12  2020  60 anos ou mais    207
# 13  2021     00 a 17 anos  16820
# 14  2021     18 a 29 anos   3457
# 15  2021     30 a 59 anos   2856
# 16  2021  60 anos ou mais    205
# 17  2022     00 a 17 anos  20584
# 18  2022     18 a 29 anos   4449
# 19  2022     30 a 59 anos   3592
# 20  2022  60 anos ou mais    251

# %%
#gráfico sinan faixa etária -  linear

sinan_faixa['Ano'] = sinan_faixa['Ano'].astype(str)

grafico_sinan_faixa = px.line(sinan_faixa, x="Ano", y="Sinan", color='faixa_etaria', markers=True,
              title="Número de Casos por Faixa Etária ao Longo dos Anos (Escala Linear) do SINAN",
              labels={"Sinan": "Número de Casos (Sinan)", "Ano": "Ano", "Faixa Etária": "faixa_etária"})
# Definindo os valores e os textos do eixo Y manualmente
max_value = sinan_faixa['Sinan'].max()
tick_values = np.arange(0, max_value + 2000, 2000)  # Isso criará um array de 0 até o valor máximo, com incrementos de 500
tick_texts = [f'{int(value)}' for value in tick_values]  # Isso converte os valores para texto sem a abreviação 'k'

# Aplicando as configurações ao eixo Y
grafico_sinan_faixa.update_yaxes(type='linear', tickmode='array', tickvals=tick_values, ticktext=tick_texts)

# Exibindo o gráfico
grafico_sinan_faixa.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="499835cc-0cd2-456d-abbe-e78356efdaa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("499835cc-0cd2-456d-abbe-e78356efdaa2")) {                    Plotly.newPlot(                        "499835cc-0cd2-456d-abbe-e78356efdaa2",                        [{"hovertemplate":"faixa_etaria=00 a 17 anos\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"00 a 17 anos","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"00 a 17 anos","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[14241,15808,13551,16820,20584],"yaxis":"y","type":"scatter"},{"hovertemplate":"faixa_etaria=18 a 29 anos\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"18 a 29 anos","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"18 a 29 anos","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[3143,3540,3213,3457,4449],"yaxis":"y","type":"scatter"},{"hovertemplate":"faixa_etaria=30 a 59 anos\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"30 a 59 anos","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"30 a 59 anos","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[2330,2719,2327,2856,3592],"yaxis":"y","type":"scatter"},{"hovertemplate":"faixa_etaria=60 anos ou mais\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"60 anos ou mais","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"60 anos ou mais","orientation":"v","showlegend":true,"x":["2018","2019","2020","2021","2022"],"xaxis":"x","y":[183,207,207,205,251],"yaxis":"y","type":"scatter"},{"hovertemplate":"faixa_etaria=Sem informa\u00e7\u00e3o\u003cbr\u003eAno=%{x}\u003cbr\u003eN\u00famero de Casos (Sinan)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sem informa\u00e7\u00e3o","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Sem informa\u00e7\u00e3o","orientation":"v","showlegend":true,"x":["2019"],"xaxis":"x","y":[28],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %%
#groupby para mapa de casos

sinesp_mapa = sinesp_oficial.groupby(["UF"])[["Sinesp"]].sum().reset_index()
sinesp_mapa.to_csv('sinesp_mapa.csv', index=False)

# %%
sinan_mapa = sinan_oficial.groupby(["UF"])[["Sinan"]].sum().reset_index()
sinan_mapa.to_csv('sinan_mapa.csv', index=False)
